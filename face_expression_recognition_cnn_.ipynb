# %% [markdown]
# ## Load our dataset
# #### Display some images from our dataset
# #### Dataset contain images from seven different Categories

# %%
# display some images for every different expression

import numpy as np
import seaborn as sns
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os

# size of the image: 48*48 pixels
pic_size = 48

# input path for the images
base_path = "../input/face-expression-recognition-dataset/images/"

plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train"):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Image augmentation using keras ImageDataGenerator

# %%
# building data generator

from keras.preprocessing.image import ImageDataGenerator

batch_size = 128
base_path = "../input/face-expression-recognition-dataset/images/"


train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   rotation_range = 20,
                                   horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale= 1.0/255)

train_generator = train_datagen.flow_from_directory(base_path + "train",
                                                    target_size=(56,56),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(base_path + "validation",
                                                    target_size=(56,56),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# # Defining our 4 Convolution and 2 Dense layers model

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam

# number of possible label values
nb_classes = 7

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(56, 56,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))

print(model.summary())

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 56, 56, 64)        640
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 56, 56, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 128)       204928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_7 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 512)       590336
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 14, 14, 512)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 7, 7, 512)         0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_10 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________
# None

# %%
# %%time

# number of epochs to train the NN
epochs = 100

# checkpoint to save best model
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# Epoch 1/100
# 225/225 [==============================] - ETA: 0s - loss: 2.0501 - accuracy: 0.2188
# Epoch 00001: val_accuracy improved from -inf to 0.22230, saving model to model_weights.h5
# 225/225 [==============================] - 42s 187ms/step - loss: 2.0501 - accuracy: 0.2188 - val_loss: 1.8450 - val_accuracy: 0.2223
# Epoch 2/100
# 225/225 [==============================] - ETA: 0s - loss: 1.9149 - accuracy: 0.2440
# Epoch 00002: val_accuracy improved from 0.22230 to 0.26349, saving model to model_weights.h5
# 225/225 [==============================] - 41s 181ms/step - loss: 1.9149 - accuracy: 0.2440 - val_loss: 1.8322 - val_accuracy: 0.2635
# Epoch 3/100
# 225/225 [==============================] - ETA: 0s - loss: 1.8671 - accuracy: 0.2569
# Epoch 00003: val_accuracy improved from 0.26349 to 0.30142, saving model to model_weights.h5
# 225/225 [==============================] - 41s 182ms/step - loss: 1.8671 - accuracy: 0.2569 - val_loss: 1.7387 - val_accuracy: 0.3014
# Epoch 4/100
# 225/225 [==============================] - ETA: 0s - loss: 1.8059 - accuracy: 0.2885
# Epoch 00004: val_accuracy improved from 0.30142 to 0.32685, saving model to model_weights.h5
# 225/225 [==============================] - 41s 183ms/step - loss: 1.8059 - accuracy: 0.2885 - val_loss: 1.6937 - val_accuracy: 0.3268
# Epoch 5/100
# 225/225 [==============================] - ETA: 0s - loss: 1.7527 - accuracy: 0.3126
# Epoch 00005: val_accuracy improved from 0.32685 to 0.35980, saving model to model_weights.h5
# 225/225 [==============================] - 41s 182ms/step - loss: 1.7527 - accuracy: 0.3126 - val_loss: 1.6703 - val_accuracy: 0.3598
# Epoch 6/100
# 225/225 [==============================] - ETA: 0s - loss: 1.7126 - accuracy: 0.3303
# Epoch 00006: val_accuracy improved from 0.35980 to 0.36903, saving model to model_weights.h5
# 225/225 [==============================] - 41s 182ms/step - loss: 1.7126 - accuracy: 0.3303 - val_loss: 1.6824 - val_accuracy: 0.3690
# Epoch 7/100
# 225/225 [==============================] - ETA: 0s - loss: 1.6629 - accuracy: 0.3495
# Epoch 00007: val_accuracy improved from 0.36903 to 0.37884, saving model to model_weights.h5
# 225/225 [==============================] - 42s 187ms/step - loss: 1.6629 - accuracy: 0.3495 - val_loss: 1.6861 - val_accuracy: 0.3788
# Epoch 8/100
# 225/225 [==============================] - ETA: 0s - loss: 1.6249 - accuracy: 0.3631
# Epoch 00008: val_accuracy improved from 0.37884 to 0.42614, saving model to model_weights.h5
# 225/225 [==============================] - 41s 184ms/step - loss: 1.6249 - accuracy: 0.3631 - val_loss: 1.4876 - val_accuracy: 0.4261
# Epoch 9/100
# 225/225 [==============================] - ETA: 0s - loss: 1.5871 - accuracy: 0.3821
# Epoch 00009: val_accuracy did not improve from 0.42614
# 225/225 [==============================] - 42s 185ms/step - loss: 1.5871 - accuracy: 0.3821 - val_loss: 1.5529 - val_accuracy: 0.4178
# Epoch 10/100
# 225/225 [==============================] - ETA: 0s - loss: 1.5606 - accuracy: 0.3922
# Epoch 00010: val_accuracy improved from 0.42614 to 0.44986, saving model to model_weights.h5
# 225/225 [==============================] - 42s 185ms/step - loss: 1.5606 - accuracy: 0.3922 - val_loss: 1.4363 - val_accuracy: 0.4499
# Epoch 11/100
# 225/225 [==============================] - ETA: 0s - loss: 1.5294 - accuracy: 0.4053
# Epoch 00011: val_accuracy improved from 0.44986 to 0.45795, saving model to model_weights.h5
# 225/225 [==============================] - 42s 184ms/step - loss: 1.5294 - accuracy: 0.4053 - val_loss: 1.4375 - val_accuracy: 0.4580
# Epoch 12/100
# 225/225 [==============================] - ETA: 0s - loss: 1.5027 - accuracy: 0.4184
# Epoch 00012: val_accuracy improved from 0.45795 to 0.47202, saving model to model_weights.h5
# 225/225 [==============================] - 42s 187ms/step - loss: 1.5027 - accuracy: 0.4184 - val_loss: 1.3641 - val_accuracy: 0.4720
# Epoch 13/100
# 225/225 [==============================] - ETA: 0s - loss: 1.4681 - accuracy: 0.4320
# Epoch 00013: val_accuracy improved from 0.47202 to 0.48196, saving model to model_weights.h5
# 225/225 [==============================] - 41s 183ms/step - loss: 1.4681 - accuracy: 0.4320 - val_loss: 1.3605 - val_accuracy: 0.4820
# Epoch 14/100
# 225/225 [==============================] - ETA: 0s - loss: 1.4459 - accuracy: 0.4418
# Epoch 00014: val_accuracy improved from 0.48196 to 0.48651, saving model to model_weights.h5
# 225/225 [==============================] - 41s 183ms/step - loss: 1.4459 - accuracy: 0.4418 - val_loss: 1.3637 - val_accuracy: 0.4865
# Epoch 15/100
# 225/225 [==============================] - ETA: 0s - loss: 1.4136 - accuracy: 0.4520
# Epoch 00015: val_accuracy improved from 0.48651 to 0.49659, saving model to model_weights.h5
# 225/225 [==============================] - 42s 185ms/step - loss: 1.4136 - accuracy: 0.4520 - val_loss: 1.3317 - val_accuracy: 0.4966
# Epoch 16/100
# 225/225 [==============================] - ETA: 0s - loss: 1.3931 - accuracy: 0.4599
# Epoch 00016: val_accuracy improved from 0.49659 to 0.53409, saving model to model_weights.h5
# 225/225 [==============================] - 40s 179ms/step - loss: 1.3931 - accuracy: 0.4599 - val_loss: 1.2373 - val_accuracy: 0.5341
# Epoch 17/100
# 225/225 [==============================] - ETA: 0s - loss: 1.3776 - accuracy: 0.4702
# Epoch 00017: val_accuracy did not improve from 0.53409
# 225/225 [==============================] - 41s 180ms/step - loss: 1.3776 - accuracy: 0.4702 - val_loss: 1.2810 - val_accuracy: 0.5159
# Epoch 18/100
# 225/225 [==============================] - ETA: 0s - loss: 1.3511 - accuracy: 0.4821
# Epoch 00018: val_accuracy improved from 0.53409 to 0.53963, saving model to model_weights.h5
# 225/225 [==============================] - 40s 178ms/step - loss: 1.3511 - accuracy: 0.4821 - val_loss: 1.2124 - val_accuracy: 0.5396
# Epoch 19/100
# 225/225 [==============================] - ETA: 0s - loss: 1.3386 - accuracy: 0.4842
# Epoch 00019: val_accuracy improved from 0.53963 to 0.55000, saving model to model_weights.h5
# 225/225 [==============================] - 40s 177ms/step - loss: 1.3386 - accuracy: 0.4842 - val_loss: 1.1998 - val_accuracy: 0.5500
# Epoch 20/100
# 225/225 [==============================] - ETA: 0s - loss: 1.3207 - accuracy: 0.4959
# Epoch 00020: val_accuracy did not improve from 0.55000
# 225/225 [==============================] - 41s 181ms/step - loss: 1.3207 - accuracy: 0.4959 - val_loss: 1.1869 - val_accuracy: 0.5393
# Epoch 21/100
# 225/225 [==============================] - ETA: 0s - loss: 1.3087 - accuracy: 0.4971
# Epoch 00021: val_accuracy did not improve from 0.55000
# 225/225 [==============================] - 40s 180ms/step - loss: 1.3087 - accuracy: 0.4971 - val_loss: 1.2483 - val_accuracy: 0.5322
# Epoch 22/100
# 225/225 [==============================] - ETA: 0s - loss: 1.2929 - accuracy: 0.5073
# Epoch 00022: val_accuracy improved from 0.55000 to 0.55781, saving model to model_weights.h5
# 225/225 [==============================] - 40s 177ms/step - loss: 1.2929 - accuracy: 0.5073 - val_loss: 1.1658 - val_accuracy: 0.5578
# Epoch 23/100
# 225/225 [==============================] - ETA: 0s - loss: 1.2801 - accuracy: 0.5113
# Epoch 00023: val_accuracy did not improve from 0.55781
# 225/225 [==============================] - 41s 180ms/step - loss: 1.2801 - accuracy: 0.5113 - val_loss: 1.1726 - val_accuracy: 0.5558
# Epoch 24/100
# 225/225 [==============================] - ETA: 0s - loss: 1.2632 - accuracy: 0.5128
# Epoch 00024: val_accuracy did not improve from 0.55781
# 225/225 [==============================] - 41s 181ms/step - loss: 1.2632 - accuracy: 0.5128 - val_loss: 1.1889 - val_accuracy: 0.5474
# Epoch 25/100
# 225/225 [==============================] - ETA: 0s - loss: 1.2500 - accuracy: 0.5224
# Epoch 00025: val_accuracy improved from 0.55781 to 0.56733, saving model to model_weights.h5
# 225/225 [==============================] - 40s 178ms/step - loss: 1.2500 - accuracy: 0.5224 - val_loss: 1.1433 - val_accuracy: 0.5673
# Epoch 26/100
# 225/225 [==============================] - ETA: 0s - loss: 1.2332 - accuracy: 0.5261
# Epoch 00026: val_accuracy improved from 0.56733 to 0.58366, saving model to model_weights.h5
# 225/225 [==============================] - 41s 182ms/step - loss: 1.2332 - accuracy: 0.5261 - val_loss: 1.1056 - val_accuracy: 0.5837
# Epoch 27/100
# 225/225 [==============================] - ETA: 0s - loss: 1.2280 - accuracy: 0.5317
# Epoch 00027: val_accuracy improved from 0.58366 to 0.58565, saving model to model_weights.h5
# 225/225 [==============================] - 40s 178ms/step - loss: 1.2280 - accuracy: 0.5317 - val_loss: 1.0980 - val_accuracy: 0.5857
# Epoch 28/100
# 225/225 [==============================] - ETA: 0s - loss: 1.2216 - accuracy: 0.5333
# Epoch 00028: val_accuracy did not improve from 0.58565
# 225/225 [==============================] - 40s 177ms/step - loss: 1.2216 - accuracy: 0.5333 - val_loss: 1.1408 - val_accuracy: 0.5740
# Epoch 29/100
# 225/225 [==============================] - ETA: 0s - loss: 1.2115 - accuracy: 0.5374
# Epoch 00029: val_accuracy did not improve from 0.58565
# 225/225 [==============================] - 40s 178ms/step - loss: 1.2115 - accuracy: 0.5374 - val_loss: 1.2175 - val_accuracy: 0.5375
# Epoch 30/100
# 225/225 [==============================] - ETA: 0s - loss: 1.2023 - accuracy: 0.5393
# Epoch 00030: val_accuracy improved from 0.58565 to 0.58920, saving model to model_weights.h5
# 225/225 [==============================] - 41s 182ms/step - loss: 1.2023 - accuracy: 0.5393 - val_loss: 1.0892 - val_accuracy: 0.5892
# Epoch 31/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1914 - accuracy: 0.5486
# Epoch 00031: val_accuracy improved from 0.58920 to 0.58977, saving model to model_weights.h5
# 225/225 [==============================] - 40s 179ms/step - loss: 1.1914 - accuracy: 0.5486 - val_loss: 1.0911 - val_accuracy: 0.5898
# Epoch 32/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1874 - accuracy: 0.5474
# Epoch 00032: val_accuracy did not improve from 0.58977
# 225/225 [==============================] - 40s 179ms/step - loss: 1.1874 - accuracy: 0.5474 - val_loss: 1.1338 - val_accuracy: 0.5628
# Epoch 33/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1760 - accuracy: 0.5519
# Epoch 00033: val_accuracy did not improve from 0.58977
# 225/225 [==============================] - 40s 178ms/step - loss: 1.1760 - accuracy: 0.5519 - val_loss: 1.0993 - val_accuracy: 0.5865
# Epoch 34/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1685 - accuracy: 0.5551
# Epoch 00034: val_accuracy did not improve from 0.58977
# 225/225 [==============================] - 40s 178ms/step - loss: 1.1685 - accuracy: 0.5551 - val_loss: 1.0838 - val_accuracy: 0.5832
# Epoch 35/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1618 - accuracy: 0.5583
# Epoch 00035: val_accuracy improved from 0.58977 to 0.59560, saving model to model_weights.h5
# 225/225 [==============================] - 40s 178ms/step - loss: 1.1618 - accuracy: 0.5583 - val_loss: 1.0750 - val_accuracy: 0.5956
# Epoch 36/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1506 - accuracy: 0.5602
# Epoch 00036: val_accuracy did not improve from 0.59560
# 225/225 [==============================] - 40s 176ms/step - loss: 1.1506 - accuracy: 0.5602 - val_loss: 1.1107 - val_accuracy: 0.5793
# Epoch 37/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1488 - accuracy: 0.5639
# Epoch 00037: val_accuracy did not improve from 0.59560
# 225/225 [==============================] - 39s 175ms/step - loss: 1.1488 - accuracy: 0.5639 - val_loss: 1.1198 - val_accuracy: 0.5713
# Epoch 38/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1417 - accuracy: 0.5654
# Epoch 00038: val_accuracy improved from 0.59560 to 0.61023, saving model to model_weights.h5
# 225/225 [==============================] - 41s 181ms/step - loss: 1.1417 - accuracy: 0.5654 - val_loss: 1.0374 - val_accuracy: 0.6102
# Epoch 39/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1365 - accuracy: 0.5669
# Epoch 00039: val_accuracy did not improve from 0.61023
# 225/225 [==============================] - 40s 179ms/step - loss: 1.1365 - accuracy: 0.5669 - val_loss: 1.0488 - val_accuracy: 0.6020
# Epoch 40/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1256 - accuracy: 0.5720
# Epoch 00040: val_accuracy did not improve from 0.61023
# 225/225 [==============================] - 40s 177ms/step - loss: 1.1256 - accuracy: 0.5720 - val_loss: 1.0529 - val_accuracy: 0.6011
# Epoch 41/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1153 - accuracy: 0.5726
# Epoch 00041: val_accuracy did not improve from 0.61023
# 225/225 [==============================] - 39s 174ms/step - loss: 1.1153 - accuracy: 0.5726 - val_loss: 1.0738 - val_accuracy: 0.5976
# Epoch 42/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1151 - accuracy: 0.5743
# Epoch 00042: val_accuracy did not improve from 0.61023
# 225/225 [==============================] - 39s 174ms/step - loss: 1.1151 - accuracy: 0.5743 - val_loss: 1.1580 - val_accuracy: 0.5598
# Epoch 43/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1071 - accuracy: 0.5792
# Epoch 00043: val_accuracy improved from 0.61023 to 0.61051, saving model to model_weights.h5
# 225/225 [==============================] - 40s 178ms/step - loss: 1.1071 - accuracy: 0.5792 - val_loss: 1.0277 - val_accuracy: 0.6105
# Epoch 44/100
# 225/225 [==============================] - ETA: 0s - loss: 1.1057 - accuracy: 0.5843
# Epoch 00044: val_accuracy improved from 0.61051 to 0.61449, saving model to model_weights.h5
# 225/225 [==============================] - 40s 179ms/step - loss: 1.1057 - accuracy: 0.5843 - val_loss: 1.0292 - val_accuracy: 0.6145
# Epoch 45/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.5802
# Epoch 00045: val_accuracy improved from 0.61449 to 0.61790, saving model to model_weights.h5
# 225/225 [==============================] - 40s 179ms/step - loss: 1.0986 - accuracy: 0.5802 - val_loss: 1.0075 - val_accuracy: 0.6179
# Epoch 46/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0868 - accuracy: 0.5902
# Epoch 00046: val_accuracy did not improve from 0.61790
# 225/225 [==============================] - 41s 181ms/step - loss: 1.0868 - accuracy: 0.5902 - val_loss: 1.0387 - val_accuracy: 0.6077
# Epoch 47/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0864 - accuracy: 0.5881
# Epoch 00047: val_accuracy improved from 0.61790 to 0.62116, saving model to model_weights.h5
# 225/225 [==============================] - 41s 182ms/step - loss: 1.0864 - accuracy: 0.5881 - val_loss: 1.0070 - val_accuracy: 0.6212
# Epoch 48/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0840 - accuracy: 0.5854
# Epoch 00048: val_accuracy did not improve from 0.62116
# 225/225 [==============================] - 41s 180ms/step - loss: 1.0840 - accuracy: 0.5854 - val_loss: 1.0235 - val_accuracy: 0.6159
# Epoch 49/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0786 - accuracy: 0.5901
# Epoch 00049: val_accuracy did not improve from 0.62116
# 225/225 [==============================] - 40s 179ms/step - loss: 1.0786 - accuracy: 0.5901 - val_loss: 1.0417 - val_accuracy: 0.6061
# Epoch 50/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0729 - accuracy: 0.5928
# Epoch 00050: val_accuracy improved from 0.62116 to 0.62145, saving model to model_weights.h5
# 225/225 [==============================] - 42s 185ms/step - loss: 1.0729 - accuracy: 0.5928 - val_loss: 1.0124 - val_accuracy: 0.6214
# Epoch 51/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0582 - accuracy: 0.5995
# Epoch 00051: val_accuracy did not improve from 0.62145
# 225/225 [==============================] - 40s 180ms/step - loss: 1.0582 - accuracy: 0.5995 - val_loss: 1.0229 - val_accuracy: 0.6159
# Epoch 52/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0621 - accuracy: 0.5969
# Epoch 00052: val_accuracy did not improve from 0.62145
# 225/225 [==============================] - 40s 179ms/step - loss: 1.0621 - accuracy: 0.5969 - val_loss: 1.0532 - val_accuracy: 0.6028
# Epoch 53/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0569 - accuracy: 0.5979
# Epoch 00053: val_accuracy improved from 0.62145 to 0.62301, saving model to model_weights.h5
# 225/225 [==============================] - 41s 181ms/step - loss: 1.0569 - accuracy: 0.5979 - val_loss: 1.0208 - val_accuracy: 0.6230
# Epoch 54/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0548 - accuracy: 0.6003
# Epoch 00054: val_accuracy improved from 0.62301 to 0.62670, saving model to model_weights.h5
# 225/225 [==============================] - 41s 182ms/step - loss: 1.0548 - accuracy: 0.6003 - val_loss: 0.9984 - val_accuracy: 0.6267
# Epoch 55/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0433 - accuracy: 0.6047
# Epoch 00055: val_accuracy did not improve from 0.62670
# 225/225 [==============================] - 40s 178ms/step - loss: 1.0433 - accuracy: 0.6047 - val_loss: 1.0095 - val_accuracy: 0.6237
# Epoch 56/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0422 - accuracy: 0.6031
# Epoch 00056: val_accuracy did not improve from 0.62670
# 225/225 [==============================] - 41s 180ms/step - loss: 1.0422 - accuracy: 0.6031 - val_loss: 1.0383 - val_accuracy: 0.6129
# Epoch 57/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0440 - accuracy: 0.6042
# Epoch 00057: val_accuracy improved from 0.62670 to 0.62955, saving model to model_weights.h5
# 225/225 [==============================] - 41s 184ms/step - loss: 1.0440 - accuracy: 0.6042 - val_loss: 0.9943 - val_accuracy: 0.6295
# Epoch 58/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0392 - accuracy: 0.6052
# Epoch 00058: val_accuracy improved from 0.62955 to 0.63892, saving model to model_weights.h5
# 225/225 [==============================] - 41s 182ms/step - loss: 1.0392 - accuracy: 0.6052 - val_loss: 0.9858 - val_accuracy: 0.6389
# Epoch 59/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0299 - accuracy: 0.6089
# Epoch 00059: val_accuracy did not improve from 0.63892
# 225/225 [==============================] - 40s 176ms/step - loss: 1.0299 - accuracy: 0.6089 - val_loss: 0.9825 - val_accuracy: 0.6332
# Epoch 60/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0253 - accuracy: 0.6119
# Epoch 00060: val_accuracy improved from 0.63892 to 0.64304, saving model to model_weights.h5
# 225/225 [==============================] - 40s 180ms/step - loss: 1.0253 - accuracy: 0.6119 - val_loss: 0.9700 - val_accuracy: 0.6430
# Epoch 61/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0252 - accuracy: 0.6128
# Epoch 00061: val_accuracy did not improve from 0.64304
# 225/225 [==============================] - 40s 177ms/step - loss: 1.0252 - accuracy: 0.6128 - val_loss: 0.9896 - val_accuracy: 0.6339
# Epoch 62/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0160 - accuracy: 0.6155
# Epoch 00062: val_accuracy did not improve from 0.64304
# 225/225 [==============================] - 40s 176ms/step - loss: 1.0160 - accuracy: 0.6155 - val_loss: 0.9835 - val_accuracy: 0.6320
# Epoch 63/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0216 - accuracy: 0.6134
# Epoch 00063: val_accuracy did not improve from 0.64304
# 225/225 [==============================] - 40s 179ms/step - loss: 1.0216 - accuracy: 0.6134 - val_loss: 0.9958 - val_accuracy: 0.6268
# Epoch 64/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0112 - accuracy: 0.6189
# Epoch 00064: val_accuracy did not improve from 0.64304
# 225/225 [==============================] - 41s 184ms/step - loss: 1.0112 - accuracy: 0.6189 - val_loss: 1.0262 - val_accuracy: 0.6162
# Epoch 65/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0055 - accuracy: 0.6187
# Epoch 00065: val_accuracy did not improve from 0.64304
# 225/225 [==============================] - 40s 180ms/step - loss: 1.0055 - accuracy: 0.6187 - val_loss: 0.9841 - val_accuracy: 0.6369
# Epoch 66/100
# 225/225 [==============================] - ETA: 0s - loss: 1.0020 - accuracy: 0.6184
# Epoch 00066: val_accuracy did not improve from 0.64304
# 225/225 [==============================] - 41s 180ms/step - loss: 1.0020 - accuracy: 0.6184 - val_loss: 1.0038 - val_accuracy: 0.6263
# Epoch 67/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9976 - accuracy: 0.6227
# Epoch 00067: val_accuracy did not improve from 0.64304
# 225/225 [==============================] - 41s 183ms/step - loss: 0.9976 - accuracy: 0.6227 - val_loss: 0.9799 - val_accuracy: 0.6351
# Epoch 68/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9930 - accuracy: 0.6261
# Epoch 00068: val_accuracy did not improve from 0.64304
# 225/225 [==============================] - 42s 185ms/step - loss: 0.9930 - accuracy: 0.6261 - val_loss: 0.9828 - val_accuracy: 0.6365
# Epoch 69/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9921 - accuracy: 0.6247
# Epoch 00069: val_accuracy did not improve from 0.64304
# 225/225 [==============================] - 41s 182ms/step - loss: 0.9921 - accuracy: 0.6247 - val_loss: 0.9697 - val_accuracy: 0.6403
# Epoch 70/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9847 - accuracy: 0.6260
# Epoch 00070: val_accuracy improved from 0.64304 to 0.64645, saving model to model_weights.h5
# 225/225 [==============================] - 40s 179ms/step - loss: 0.9847 - accuracy: 0.6260 - val_loss: 0.9746 - val_accuracy: 0.6464
# Epoch 71/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9875 - accuracy: 0.6254
# Epoch 00071: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 41s 182ms/step - loss: 0.9875 - accuracy: 0.6254 - val_loss: 0.9928 - val_accuracy: 0.6341
# Epoch 72/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9788 - accuracy: 0.6302
# Epoch 00072: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 42s 186ms/step - loss: 0.9788 - accuracy: 0.6302 - val_loss: 0.9961 - val_accuracy: 0.6293
# Epoch 73/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9780 - accuracy: 0.6316
# Epoch 00073: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 42s 188ms/step - loss: 0.9780 - accuracy: 0.6316 - val_loss: 0.9832 - val_accuracy: 0.6338
# Epoch 74/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9778 - accuracy: 0.6279
# Epoch 00074: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 44s 196ms/step - loss: 0.9778 - accuracy: 0.6279 - val_loss: 1.0229 - val_accuracy: 0.6182
# Epoch 75/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9674 - accuracy: 0.6336
# Epoch 00075: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 46s 204ms/step - loss: 0.9674 - accuracy: 0.6336 - val_loss: 1.0120 - val_accuracy: 0.6291
# Epoch 76/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9650 - accuracy: 0.6398
# Epoch 00076: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 44s 196ms/step - loss: 0.9650 - accuracy: 0.6398 - val_loss: 1.0002 - val_accuracy: 0.6293
# Epoch 77/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9639 - accuracy: 0.6381
# Epoch 00077: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 44s 193ms/step - loss: 0.9639 - accuracy: 0.6381 - val_loss: 0.9916 - val_accuracy: 0.6293
# Epoch 78/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9612 - accuracy: 0.6369
# Epoch 00078: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 44s 195ms/step - loss: 0.9612 - accuracy: 0.6369 - val_loss: 0.9718 - val_accuracy: 0.6443
# Epoch 79/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9643 - accuracy: 0.6354
# Epoch 00079: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 45s 198ms/step - loss: 0.9643 - accuracy: 0.6354 - val_loss: 0.9656 - val_accuracy: 0.6438
# Epoch 80/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9606 - accuracy: 0.6357
# Epoch 00080: val_accuracy did not improve from 0.64645
# 225/225 [==============================] - 43s 190ms/step - loss: 0.9606 - accuracy: 0.6357 - val_loss: 0.9741 - val_accuracy: 0.6393
# Epoch 81/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9532 - accuracy: 0.6388
# Epoch 00081: val_accuracy improved from 0.64645 to 0.65341, saving model to model_weights.h5
# 225/225 [==============================] - 43s 192ms/step - loss: 0.9532 - accuracy: 0.6388 - val_loss: 0.9366 - val_accuracy: 0.6534
# Epoch 82/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9571 - accuracy: 0.6407
# Epoch 00082: val_accuracy did not improve from 0.65341
# 225/225 [==============================] - 42s 187ms/step - loss: 0.9571 - accuracy: 0.6407 - val_loss: 0.9428 - val_accuracy: 0.6507
# Epoch 83/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9470 - accuracy: 0.6419
# Epoch 00083: val_accuracy did not improve from 0.65341
# 225/225 [==============================] - 41s 182ms/step - loss: 0.9470 - accuracy: 0.6419 - val_loss: 0.9328 - val_accuracy: 0.6531
# Epoch 84/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9438 - accuracy: 0.6440
# Epoch 00084: val_accuracy did not improve from 0.65341
# 225/225 [==============================] - 40s 179ms/step - loss: 0.9438 - accuracy: 0.6440 - val_loss: 0.9500 - val_accuracy: 0.6474
# Epoch 85/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9359 - accuracy: 0.6475
# Epoch 00085: val_accuracy did not improve from 0.65341
# 225/225 [==============================] - 40s 177ms/step - loss: 0.9359 - accuracy: 0.6475 - val_loss: 0.9674 - val_accuracy: 0.6453
# Epoch 86/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9358 - accuracy: 0.6460
# Epoch 00086: val_accuracy did not improve from 0.65341
# 225/225 [==============================] - 40s 178ms/step - loss: 0.9358 - accuracy: 0.6460 - val_loss: 0.9754 - val_accuracy: 0.6369
# Epoch 87/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9354 - accuracy: 0.6464
# Epoch 00087: val_accuracy did not improve from 0.65341
# 225/225 [==============================] - 41s 181ms/step - loss: 0.9354 - accuracy: 0.6464 - val_loss: 0.9671 - val_accuracy: 0.6482
# Epoch 88/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9288 - accuracy: 0.6511
# Epoch 00088: val_accuracy improved from 0.65341 to 0.65469, saving model to model_weights.h5
# 225/225 [==============================] - 41s 181ms/step - loss: 0.9288 - accuracy: 0.6511 - val_loss: 0.9400 - val_accuracy: 0.6547
# Epoch 89/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9239 - accuracy: 0.6518
# Epoch 00089: val_accuracy did not improve from 0.65469
# 225/225 [==============================] - 40s 177ms/step - loss: 0.9239 - accuracy: 0.6518 - val_loss: 0.9829 - val_accuracy: 0.6389
# Epoch 90/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9217 - accuracy: 0.6521
# Epoch 00090: val_accuracy improved from 0.65469 to 0.66349, saving model to model_weights.h5
# 225/225 [==============================] - 40s 180ms/step - loss: 0.9217 - accuracy: 0.6521 - val_loss: 0.9187 - val_accuracy: 0.6635
# Epoch 91/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9227 - accuracy: 0.6494
# Epoch 00091: val_accuracy did not improve from 0.66349
# 225/225 [==============================] - 41s 181ms/step - loss: 0.9227 - accuracy: 0.6494 - val_loss: 0.9557 - val_accuracy: 0.6531
# Epoch 92/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9185 - accuracy: 0.6516
# Epoch 00092: val_accuracy did not improve from 0.66349
# 225/225 [==============================] - 40s 176ms/step - loss: 0.9185 - accuracy: 0.6516 - val_loss: 0.9764 - val_accuracy: 0.6362
# Epoch 93/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9073 - accuracy: 0.6564
# Epoch 00093: val_accuracy did not improve from 0.66349
# 225/225 [==============================] - 40s 177ms/step - loss: 0.9073 - accuracy: 0.6564 - val_loss: 1.0140 - val_accuracy: 0.6303
# Epoch 94/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9199 - accuracy: 0.6507
# Epoch 00094: val_accuracy did not improve from 0.66349
# 225/225 [==============================] - 40s 177ms/step - loss: 0.9199 - accuracy: 0.6507 - val_loss: 0.9772 - val_accuracy: 0.6384
# Epoch 95/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9035 - accuracy: 0.6600
# Epoch 00095: val_accuracy did not improve from 0.66349
# 225/225 [==============================] - 39s 175ms/step - loss: 0.9035 - accuracy: 0.6600 - val_loss: 0.9410 - val_accuracy: 0.6514
# Epoch 96/100
# 225/225 [==============================] - ETA: 0s - loss: 0.8998 - accuracy: 0.6607
# Epoch 00096: val_accuracy did not improve from 0.66349
# 225/225 [==============================] - 39s 175ms/step - loss: 0.8998 - accuracy: 0.6607 - val_loss: 0.9432 - val_accuracy: 0.6521
# Epoch 97/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9029 - accuracy: 0.6605
# Epoch 00097: val_accuracy did not improve from 0.66349
# 225/225 [==============================] - 40s 176ms/step - loss: 0.9029 - accuracy: 0.6605 - val_loss: 0.9452 - val_accuracy: 0.6510
# Epoch 98/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9068 - accuracy: 0.6553
# Epoch 00098: val_accuracy did not improve from 0.66349
# 225/225 [==============================] - 40s 177ms/step - loss: 0.9068 - accuracy: 0.6553 - val_loss: 1.0088 - val_accuracy: 0.6253
# Epoch 99/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9027 - accuracy: 0.6609
# Epoch 00099: val_accuracy improved from 0.66349 to 0.66520, saving model to model_weights.h5
# 225/225 [==============================] - 40s 178ms/step - loss: 0.9027 - accuracy: 0.6609 - val_loss: 0.9254 - val_accuracy: 0.6652
# Epoch 100/100
# 225/225 [==============================] - ETA: 0s - loss: 0.9000 - accuracy: 0.6595
# Epoch 00100: val_accuracy did not improve from 0.66520
# 225/225 [==============================] - 39s 175ms/step - loss: 0.9000 - accuracy: 0.6595 - val_loss: 0.9621 - val_accuracy: 0.6388
# CPU times: user 46min 8s, sys: 4min 18s, total: 50min 26s
# Wall time: 1h 8min 21s

# %%
# visualise training and testing accuracy and loss

def plot_results(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize = (24, 6))
    plt.subplot(1,2,1)
    plt.plot(epochs, acc, 'b', label = 'Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label = 'Validation Accuracy')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')



    plt.subplot(1,2,2)
    plt.plot(epochs, loss, 'b', label = 'Training Loss')
    plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.show()

# print best epoch with best accuracy on validation

def get_best_epcoh(history):
    valid_acc = history.history['val_accuracy']
    best_epoch = valid_acc.index(max(valid_acc)) + 1
    best_acc =  max(valid_acc)
    print('Best Validation Accuracy Score {:0.5f}, is for epoch {}'.format( best_acc, best_epoch))
    return best_epoch

# %%
plot_results(history)
best_epoch =get_best_epcoh(history)
# Out:
# Best Validation Accuracy Score 0.66520, is for epoch 99

# %% [markdown]
# ## Connecting with openCV

# %%
import numpy as np
import cv2
from tensorflow.keras.models import model_from_json

# %%
model_json_file = '.emotion_model.json'
model_weights_file = 'emotion_model.h5'
with open(model_json_file, "r") as json_file:
    loaded_model_json = json_file.read()
    loaded_model = model_from_json(loaded_model_json)
    loaded_model.load_weights(model_weights_file)
