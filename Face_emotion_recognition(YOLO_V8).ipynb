# %%
# Pip install (recommended)

# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.9/529.9 kB 31.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.8/198.8 kB 25.6 MB/s eta 0:00:00
# ...

# %%
## importing required libraries
import os
import shutil
import random

# !pip install tqdm --upgrade
from tqdm.notebook import tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
## connecting to the google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/Othercomputers/Laptop2/AI_ml_HP/AI_ML/projects/Face-emotion-detection-YOLO-v8/yolov8.zip -d /content/
# Out:
# Archive:  /content/drive/Othercomputers/Laptop2/AI_ml_HP/AI_ML/projects/Face-emotion-detection-YOLO-v8/yolov8.zip
#  extracting: /content/README.dataset.txt
#  extracting: /content/README.roboflow.txt
#  extracting: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/Angry-f4bf39e3856bb5d47676d19bae812fe62175ce8bbb55a97b233b32312e22d2a5_jpg.rf.bd5a007481c86ed450529245a80ffc85.jpg
#  extracting: /content/test/images/happy-face-045b3a390344545f6af5ca85d57a4ce7f338b1b766e7916f839cb2b7184225f2_jpg.rf.05a0a58ad44ab3c1e61f526e141eb736.jpg
#  extracting: /content/test/images/happy-face-5e8153effd5e899060a410fa92d49b7f4f80a9b779fa1f846e04d03b4aac0d92_jpg.rf.1202d76762fe6d4bd42525d1950e9b6b.jpg
#  extracting: /content/test/images/happy-face-75f1064d6691536292871916a8da8dbe486a398f1de4514231d9099e1977d0c9_jpg.rf.a79dc3e5d9afeb8e2e7f352c70449c33.jpg
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.84 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/data.yaml epochs=15 imgsz=640 batch=8 project=/content/drive/MyDrive/report  "save=True"
# Out:
# ...
# 100% 21.5M/21.5M [00:02<00:00, 10.5MB/s]
# Ultralytics YOLOv8.0.85 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/report/train2/weights/best.pt conf=0.35 source=/content/test/images  save=True
# Out:
# Ultralytics YOLOv8.0.85 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/10 /content/test/images/Angry-f4bf39e3856bb5d47676d19bae812fe62175ce8bbb55a97b233b32312e22d2a5_jpg.rf.bd5a007481c86ed450529245a80ffc85.jpg: 640x640 1 fear, 16.3ms
# image 2/10 /content/test/images/happy-face-045b3a390344545f6af5ca85d57a4ce7f338b1b766e7916f839cb2b7184225f2_jpg.rf.05a0a58ad44ab3c1e61f526e141eb736.jpg: 640x640 1 happy, 16.3ms
# image 3/10 /content/test/images/happy-face-5e8153effd5e899060a410fa92d49b7f4f80a9b779fa1f846e04d03b4aac0d92_jpg.rf.1202d76762fe6d4bd42525d1950e9b6b.jpg: 640x640 1 angry, 1 happy, 16.3ms
# image 4/10 /content/test/images/happy-face-75f1064d6691536292871916a8da8dbe486a398f1de4514231d9099e1977d0c9_jpg.rf.a79dc3e5d9afeb8e2e7f352c70449c33.jpg: 640x640 1 happy, 16.2ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/report

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/report/train/weights/best.pt conf=0.55 source=/content/drive/Othercomputers/Laptop2/AI_ml_HP/AI_ML/projects/Face-emotion-detection-YOLO-v8/video save=True
# Out:
# Ultralytics YOLOv8.0.85 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/6 (1/307) /content/drive/Othercomputers/Laptop2/AI_ml_HP/AI_ML/projects/Face-emotion-detection-YOLO-v8/video/mixkit-friends-laughing-on-a-bus-42583-medium.mp4: 384x640 (no detections), 65.5ms
# video 1/6 (2/307) /content/drive/Othercomputers/Laptop2/AI_ml_HP/AI_ML/projects/Face-emotion-detection-YOLO-v8/video/mixkit-friends-laughing-on-a-bus-42583-medium.mp4: 384x640 (no detections), 11.0ms
# video 1/6 (3/307) /content/drive/Othercomputers/Laptop2/AI_ml_HP/AI_ML/projects/Face-emotion-detection-YOLO-v8/video/mixkit-friends-laughing-on-a-bus-42583-medium.mp4: 384x640 (no detections), 11.0ms
# video 1/6 (4/307) /content/drive/Othercomputers/Laptop2/AI_ml_HP/AI_ML/projects/Face-emotion-detection-YOLO-v8/video/mixkit-friends-laughing-on-a-bus-42583-medium.mp4: 384x640 (no detections), 11.1ms
# ...

# %%
# !cp -r /content/runs/detect/predict2 /content/drive/MyDrive/report
